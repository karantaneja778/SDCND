# %%
# do necessary imports
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# read in an image
img = mpimg.imread('warped_example.jpg')/255

plt.imshow(img)

# %%
def hist(img) :
    
    # grab only bottom half of the image
    bottom_half = img[img.shape[0]//2:,:]
    
    plt.imshow(bottom_half)
    
    histogram = np.sum(bottom_half, axis=0)
    
    return histogram

# %%
histogram = hist(img)

# %%
plt.plot(histogram)
# Out:
# [<matplotlib.lines.Line2D at 0x1ea4579d7f0>,
#  <matplotlib.lines.Line2D at 0x1ea4579d9b0>,
#  <matplotlib.lines.Line2D at 0x1ea4579db00>]
